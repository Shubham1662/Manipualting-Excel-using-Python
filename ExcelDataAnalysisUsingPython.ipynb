# %% [markdown]
# # DATA ANALYSIS USING PYTHON

# %%
# Let's import import all libraris that can be used
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from datetime import date

# %%
#If we have to delete some particular file from some place in system.
#Excel file with name InputFile - Copy an extension xlsx will be deleted from below location
os.remove("F:\Study Material\MS-Excel\InputFile - Copy.xlsx")

# %%
#Now let's import the dataset that we have to work on
Orders=pd.read_excel("F:\Study Material\MS-Excel\Global Superstore_1.xlsm", sheet_name="Orders")
Returns=pd.read_excel("F:\Study Material\MS-Excel\Global Superstore_1.xlsm", sheet_name="Returns")
People=pd.read_excel("F:\Study Material\MS-Excel\Global Superstore_1.xlsm", sheet_name="People")

# %%
#Order have complete date related to particular Order
Orders.head(5)
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
Returns.head(5)
# Out:
#   Returned         Order ID         Market
# 0      Yes   MX-2013-168137          LATAM
# 1      Yes   US-2011-165316          LATAM
# 2      Yes  ES-2013-1525878             EU
# 3      Yes   CA-2013-118311  United States
# 4      Yes  ES-2011-1276768             EU

# %%
People.head(5)
# Out:
#               Person   Region
# 0      Anna Andreadi  Central
# 1        Chuck Magee    South
# 2     Kelly Williams     East
# 3     Matt Collister     West
# 4  Deborah Brumfield   Africa

# %%
Orders.shape#Total no. of Rows and columns
# Out:
# (51290, 24)

# %%
Orders.describe()#Analysing all numerical values
# Out:
#             Row ID   Postal Code         Sales      Quantity      Discount  \
# count  51290.00000   9994.000000  51290.000000  51290.000000  51290.000000
# mean   25645.50000  55190.379428    246.490581      3.476545      0.142908
# std    14806.29199  32063.693350    487.565361      2.278766      0.212280
# min        1.00000   1040.000000      0.444000      1.000000      0.000000
# 25%    12823.25000  23223.000000     30.758625      2.000000      0.000000
# 50%    25645.50000  56430.500000     85.053000      3.000000      0.000000
# 75%    38467.75000  90008.000000    251.053200      5.000000      0.200000
# max    51290.00000  99301.000000  22638.480000     14.000000      0.850000
#
#              Profit  Shipping Cost
# count  51290.000000   51290.000000
# mean      28.610982      26.375818
# std      174.340972      57.296810
# min    -6599.978000       0.002000
# 25%        0.000000       2.610000
# 50%        9.240000       7.790000
# 75%       36.810000      24.450000
# ...

# %%
Orders.isnull().sum()#To check #N/A in all columns
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
#We can see that except in postal code we don't have any #N/A in any columns

# %%
#Now from column Country, we have to remove all data that have Italy
Orders=Orders[~(Orders['Country']=='Italy')]

# %%
#Now deleting all rows that have "CA" contains in Order ID like "CA-2012-124891"
Orders=Orders[~Orders['Order ID'].str.contains('CA',na=False)]

# %%
#Now we will split Order ID into 3 parts on basis of "-" SA-2011-1830
Orders[['ID_Country','ID_Year','ID_Orders']]=Orders['Order ID'].str.split("-",expand=True)

# %%
list(Orders.columns) #to Check headers name
# Out:
# ['Row ID',
#  'Order ID',
#  'Order Date',
#  'Ship Date',
#  'Ship Mode',
#  'Customer ID',
#  'Customer Name',
#  'Segment',
#  'City',
#  'State',
#  'Country',
#  'Postal Code',
#  'Market',
#  'Region',
#  'Product ID',
#  'Category',
#  'Sub-Category',
#  'Product Name',
#  'Sales',
#  'Quantity',
#  'Discount',
#  'Profit',
#  'Shipping Cost',
#  'Order Priority',
#  'ID_Country',
#  'ID_Year',
#  'ID_Orders']

# %%
#To delete a column
Orders=Orders.drop('City',axis=1)

# %%
list(Orders.columns)#City column is deleted.
# Out:
# ['Row ID',
#  'Order ID',
#  'Order Date',
#  'Ship Date',
#  'Ship Mode',
#  'Customer ID',
#  'Customer Name',
#  'Segment',
#  'State',
#  'Country',
#  'Postal Code',
#  'Market',
#  'Region',
#  'Product ID',
#  'Category',
#  'Sub-Category',
#  'Product Name',
#  'Sales',
#  'Quantity',
#  'Discount',
#  'Profit',
#  'Shipping Cost',
#  'Order Priority',
#  'ID_Country',
#  'ID_Year',
#  'ID_Orders']

# %%
#If we have to replace values in a column
#we will replace Customer Name Justin Ritter with Matt De Blank
#Let's first check cutomer name column
Orders['Customer Name'].head(4)
# Out:
# 1       Justin Ritter
# 2        Craig Reiter
# 3    Katherine Murray
# 4         Rick Hansen
# Name: Customer Name, dtype: object

# %%
Orders['Customer Name']=Orders['Customer Name'].replace("Justin Ritter","Matt De Blank")

# %%
Orders['Customer Name'].head(4)#Customer Name Justin Ritter is replaced with Matt De Blank
# Out:
# 1       Matt De Blank
# 2        Craig Reiter
# 3    Katherine Murray
# 4         Rick Hansen
# Name: Customer Name, dtype: object

# %% [markdown]
# # Time to Use Look up Function of Excel

# %%
#For look of excel or fteching data from other excel Sheet we use Merge function in python.
#I will show with an example

# %%
#Let's check our Return data
Returns.head(6)
# Out:
#   Returned         Order ID         Market
# 0      Yes   MX-2013-168137          LATAM
# 1      Yes   US-2011-165316          LATAM
# 2      Yes  ES-2013-1525878             EU
# 3      Yes   CA-2013-118311  United States
# 4      Yes  ES-2011-1276768             EU
# 5      Yes   MX-2013-131247          LATAM

# %%
#For these Order IDs we will use our Orders dataset aand will fetch all information available
Returns=pd.merge(Returns,Orders,on='Order ID',left_index=True,right_index=False,how='left')

# %%
#Now lets check Returns
Returns.head(3)
# Out:
#       Returned        Order ID Market_x  Row ID Order Date  Ship Date  \
# 9034       Yes  MX-2013-168137    LATAM  1620.0 2013-11-06 2013-11-08
# 17126      Yes  MX-2013-168137    LATAM  1621.0 2013-11-06 2013-11-08
# 8279       Yes  US-2011-165316    LATAM  4257.0 2011-06-18 2011-06-23
#
#           Ship Mode Customer ID  Customer Name    Segment  ...  \
# 9034    First Class    AB-10105  Adrian Barton   Consumer  ...
# 17126   First Class    AB-10105  Adrian Barton   Consumer  ...
# 8279   Second Class    LO-17170     Lori Olson  Corporate  ...
#
#                            Product Name    Sales  Quantity Discount  Profit  \
# 9034         Hoover Coffee Grinder, Red  137.580       3.0      0.0  27.480
# 17126      Acco Binder Covers, Recycled   63.840       7.0      0.0   5.740
# 8279   Dania Stackable Bookrack, Mobile  518.784       8.0      0.2  58.304
#
#       Shipping Cost Order Priority ID_Country ID_Year  ID_Orders
# ...

# %%
#We can drop columns that we don't need using drop function explained above

# %%
#We can also sort Values in a column like A to Z or Newest to Oldest for date.
Orders=Orders.sort_values(["Order Date"],axis=0,ascending=False)

# %%
Orders.head(7)
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 1917    44025     RS-2014-1460 2014-12-31 2015-01-02    Second Class
# 32133   26334    IN-2014-30390 2014-12-31 2015-01-03     First Class
# 49364   47594     MO-2014-2560 2014-12-31 2015-01-05  Standard Class
# 17379   10625  ES-2014-2815584 2014-12-31 2015-01-04  Standard Class
# 18939   41744     TU-2014-5170 2014-12-31 2015-01-04    Second Class
# 3590    26333    IN-2014-30390 2014-12-31 2015-01-03     First Class
# 44497    2143   MX-2014-108574 2014-12-31 2015-01-04  Standard Class
#
#       Customer ID      Customer Name      Segment                   State  \
# 1917      PB-9105       Peter Bühler     Consumer           Bashkortostan
# 32133    JD-16150   Justin Deggeller    Corporate                 Bangkok
# 49364     LP-7095          Liz Preis     Consumer        Souss-Massa-Draâ
# 17379    ES-14020        Erica Smith     Consumer  North Rhine-Westphalia
# ...

# %% [markdown]
# # Creating a Pivot table

# %%
#Using Python we can also create Pivot Table in our excel ile
Pv1=Orders.pivot_table(values='Order ID',index=["Market","Ship Mode"],columns='Segment',margins=True,aggfunc='count')

# %% [markdown]
# # Saving Result and Pivot table in a excel sheet

# %%
Orders.to_excel(r'C:\Users\Finch\result.xlsx',sheet_name='Sheet1')
Pv1.to_excel(r'C:\Users\Finch\result.xlsx',sheet_name='Sheet2')

# %%
Pv1.to_excel(r'C:\Users\Finch\result.xlsx',sheet_name='Sheet2')
