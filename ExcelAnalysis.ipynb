# %% [markdown]
# Import the libraries needed

# %%
import pandas as pd #Here i only need pandas library

# %% [markdown]
# Import all the excel files and related sheets

# %%
orders=pd.read_excel('Global Superstore.xls',sheet_name='Orders') # First importing order sheet

# %%
orders.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298  CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341   IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
#
#    Customer Name    Segment           City            State       ...        \
# 0    Rick Hansen   Consumer  New York City         New York       ...
# 1  Justin Ritter  Corporate     Wollongong  New South Wales       ...
#
#         Product ID    Category Sub-Category  \
# 0  TEC-AC-10003033  Technology  Accessories
# 1  FUR-CH-10003950   Furniture       Chairs
#
#                                         Product Name     Sales Quantity  \
# 0  Plantronics CS510 - Over-the-Head monaural Wir...  2309.650        7
# 1          Novimex Executive Leather Armchair, Black  3709.395        9
#
#   Discount    Profit  Shipping Cost  Order Priority
# 0      0.0  762.1845         933.57        Critical
# 1      0.1 -288.7650         923.63        Critical
#
# ...

# %%
orders=orders.drop(["Customer ID","Customer Name", "Order Priority","Sales","Quantity","Discount","Profit","Product Name","Product ID"],axis=1)
# deleted columns i don't need

# %%
orders.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode    Segment  \
# 0   32298  CA-2012-124891 2012-07-31 2012-07-31      Same Day   Consumer
# 1   26341   IN-2013-77878 2013-02-05 2013-02-07  Second Class  Corporate
#
#             City            State        Country  Postal Code Market   Region  \
# 0  New York City         New York  United States      10024.0     US     East
# 1     Wollongong  New South Wales      Australia          NaN   APAC  Oceania
#
#      Category Sub-Category  Shipping Cost
# 0  Technology  Accessories         933.57
# 1   Furniture       Chairs         923.63

# %%
return_sheet = pd.read_excel('Global Superstore.xls',sheet_name='Return') # Importing return sheet from same excel file

# %%
return_sheet.head(2) # Courier aount paid by customer while returing product
# Out:
#          Order ID  CarrierPrice
# 0  CA-2012-124891           329
# 1   IN-2013-77878           479

# %%
result=orders.merge(return_sheet,on='Order ID') # Merging both the sheet like Vllokup

# %%
result.head(3)
# Out:
#    Row ID        Order ID Order Date  Ship Date Ship Mode   Segment  \
# 0   32298  CA-2012-124891 2012-07-31 2012-07-31  Same Day  Consumer
# 1   32298  CA-2012-124891 2012-07-31 2012-07-31  Same Day  Consumer
# 2   32298  CA-2012-124891 2012-07-31 2012-07-31  Same Day  Consumer
#
#             City     State        Country  Postal Code Market Region  \
# 0  New York City  New York  United States      10024.0     US   East
# 1  New York City  New York  United States      10024.0     US   East
# 2  New York City  New York  United States      10024.0     US   East
#
#      Category Sub-Category  Shipping Cost  CarrierPrice
# 0  Technology  Accessories         933.57           329
# 1  Technology  Accessories         933.57           660
# 2  Technology  Accessories         933.57           896

# %%
result.to_excel(r'C:\Users\Finch\result.xlsx') # Save the output at location C:\Users\Finch with file name as result.xlsx
